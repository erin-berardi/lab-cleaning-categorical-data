# %%
# Importing libraries
import pandas as pd
import numpy as np

# %%
# Importing data
df_customer = pd.read_csv(r"C:\Users\joaoa\Desktop\Ironhack\Labs\lab-cleaning-categorical-data\files_for_lab\we_fn_use_c_marketing_customer_value_analysis.csv")
df_customer
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
# Standardizing columns names
cols = []
for i in range(len(df_customer.columns)):
    cols.append(df_customer.columns[i].lower().replace(" ","_"))
df_customer.columns = cols
df_customer
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
# 2) Creating a new dataframe with categorical values
df_categ = df_customer.select_dtypes(include = object)
df_categ
# Out:
#      customer       state response  coverage education effective_to_date  \
# 0     BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1     QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2     AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3     WW63253  California       No     Basic  Bachelor           1/20/11
# 4     HB64268  Washington       No     Basic  Bachelor            2/3/11
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor           2/10/11
# 9130  PK87824  California      Yes  Extended   College           2/12/11
# 9131  TD14365  California       No  Extended  Bachelor            2/6/11
# 9132  UP19263  California       No  Extended   College            2/3/11
# 9133  Y167826  California       No  Extended   College           2/14/11
#
#      employmentstatus gender location_code marital_status     policy_type  \
# ...

# %%
# 3) Checking for NaN values (there are no null values, no need to deal with them)
df_categ.isna().sum()
# Out:
# customer             0
# state                0
# response             0
# coverage             0
# education            0
# effective_to_date    0
# employmentstatus     0
# gender               0
# location_code        0
# marital_status       0
# policy_type          0
# policy               0
# renew_offer_type     0
# sales_channel        0
# vehicle_class        0
# vehicle_size         0
# dtype: int64

# %%
# 4) Checking all unique values of columns
count = 1
for column in df_categ.columns.values[1:]:
    print(df_categ.columns.values[count], "unique values:", df_categ.iloc[:,count].unique())
    count += 1
# Out:
# state unique values: ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon']
# response unique values: ['No' 'Yes']
# coverage unique values: ['Basic' 'Extended' 'Premium']
# education unique values: ['Bachelor' 'College' 'Master' 'High School or Below' 'Doctor']
# effective_to_date unique values: ['2/24/11' '1/31/11' '2/19/11' '1/20/11' '2/3/11' '1/25/11' '1/18/11'
#  '1/26/11' '2/17/11' '2/21/11' '1/6/11' '2/6/11' '1/10/11' '1/17/11'
#  '1/5/11' '2/27/11' '1/14/11' '1/21/11' '2/5/11' '1/29/11' '2/28/11'
#  '2/12/11' '2/2/11' '2/7/11' '1/22/11' '2/13/11' '1/15/11' '1/8/11'
#  '1/11/11' '1/28/11' '2/8/11' '2/23/11' '1/2/11' '2/16/11' '1/27/11'
#  '1/23/11' '1/9/11' '2/11/11' '2/4/11' '2/1/11' '2/15/11' '2/26/11'
#  '1/16/11' '1/1/11' '2/10/11' '1/24/11' '2/25/11' '1/12/11' '2/9/11'
#  '1/19/11' '1/4/11' '2/14/11' '2/20/11' '2/18/11' '1/3/11' '1/13/11'
#  '1/30/11' '2/22/11' '1/7/11']
# employmentstatus unique values: ['Employed' 'Unemployed' 'Medical Leave' 'Disabled' 'Retired']
# ...

# %%
# 5) Check dtypes. Do they all make sense as categorical data?

# No, "effective_to_date" should be presented as datetime variable. I'm gonna deal with that later in this document.

df_categ.dtypes
# Out:
# customer             object
# state                object
# response             object
# coverage             object
# education            object
# effective_to_date    object
# employmentstatus     object
# gender               object
# location_code        object
# marital_status       object
# policy_type          object
# policy               object
# renew_offer_type     object
# sales_channel        object
# vehicle_class        object
# vehicle_size         object
# dtype: object

# %%
# 6) Does any column contain alpha and numeric data?

# Yes: customer, policy and renew_offer_type. The first two make sense to keep as it is. 
# In the last one, we may drop the "Offer" part and convert it to numerical variable. 
# Like this: df_wrangling["renew_offer_type"] = df_wrangling["renew_offer_type"].map({"Offer1" : 1, "Offer2" : 2, "Offer3" : 3, "Offer4" : 4})

# However, I'm gonna keep it as categorical for now. 
# Later in [lab-data-cleaning-and-wrangling] I'm gonna encode the categorical variables as shown above.

# %%
# 7) Would you choose to do anything else to clean or wrangle the categorical data?

# For example, the "customer" column is a categorical variable but each person has a different value. 
# This doesn't give us any important information to build a model. For that reason I decided to drop it.
df_categ = df_categ.drop(["customer"], axis = 1)

# %%
# 8) Compare policy_type and policy. What information is contained in these columns. Can you identify what is important?

# Yes, policy_type column is redundant because policy column gives us also that information. So we can dropp it.
df_categ = df_categ.drop(["policy_type"], axis = 1)
df_categ
# Out:
#            state response  coverage education effective_to_date  \
# 0     Washington       No     Basic  Bachelor           2/24/11
# 1        Arizona       No  Extended  Bachelor           1/31/11
# 2         Nevada       No   Premium  Bachelor           2/19/11
# 3     California       No     Basic  Bachelor           1/20/11
# 4     Washington       No     Basic  Bachelor            2/3/11
# ...          ...      ...       ...       ...               ...
# 9129  California       No     Basic  Bachelor           2/10/11
# 9130  California      Yes  Extended   College           2/12/11
# 9131  California       No  Extended  Bachelor            2/6/11
# 9132  California       No  Extended   College            2/3/11
# 9133  California       No  Extended   College           2/14/11
#
#      employmentstatus gender location_code marital_status        policy  \
# 0            Employed      F      Suburban        Married  Corporate L3
# ...

# %%
# 9) Check number of unique values in each column.
count = 0
for column in df_categ.columns.values:
    print(df_categ.columns.values[count], "unique values:", df_categ.iloc[:,count].unique())
    count += 1
# Out:
# state unique values: ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon']
# response unique values: ['No' 'Yes']
# coverage unique values: ['Basic' 'Extended' 'Premium']
# education unique values: ['Bachelor' 'College' 'Master' 'High School or Below' 'Doctor']
# effective_to_date unique values: ['2/24/11' '1/31/11' '2/19/11' '1/20/11' '2/3/11' '1/25/11' '1/18/11'
#  '1/26/11' '2/17/11' '2/21/11' '1/6/11' '2/6/11' '1/10/11' '1/17/11'
#  '1/5/11' '2/27/11' '1/14/11' '1/21/11' '2/5/11' '1/29/11' '2/28/11'
#  '2/12/11' '2/2/11' '2/7/11' '1/22/11' '2/13/11' '1/15/11' '1/8/11'
#  '1/11/11' '1/28/11' '2/8/11' '2/23/11' '1/2/11' '2/16/11' '1/27/11'
#  '1/23/11' '1/9/11' '2/11/11' '2/4/11' '2/1/11' '2/15/11' '2/26/11'
#  '1/16/11' '1/1/11' '2/10/11' '1/24/11' '2/25/11' '1/12/11' '2/9/11'
#  '1/19/11' '1/4/11' '2/14/11' '2/20/11' '2/18/11' '1/3/11' '1/13/11'
#  '1/30/11' '2/22/11' '1/7/11']
# employmentstatus unique values: ['Employed' 'Unemployed' 'Medical Leave' 'Disabled' 'Retired']
# ...

# %%
# 9) Can they be combined in any way to ease encoding? Comment your thoughts and make those changes.

# We can group the effective_to_date by the respective month so we can have only two unique values
df_categ["effective_to_date"] = df_categ["effective_to_date"].str.split("/",expand=True)[0]
df_categ.loc[df_categ["effective_to_date"] == "1", "effective_to_date"] = "jan/2011"
df_categ.loc[df_categ["effective_to_date"] == "2", "effective_to_date"] = "feb/2011"
df_categ.rename(columns = {"effective_to_date":"effective_to_date_(month)"}, inplace = True)
df_categ
# Out:
#            state response  coverage education effective_to_date_(month)  \
# 0     Washington       No     Basic  Bachelor                  feb/2011
# 1        Arizona       No  Extended  Bachelor                  jan/2011
# 2         Nevada       No   Premium  Bachelor                  feb/2011
# 3     California       No     Basic  Bachelor                  jan/2011
# 4     Washington       No     Basic  Bachelor                  feb/2011
# ...          ...      ...       ...       ...                       ...
# 9129  California       No     Basic  Bachelor                  feb/2011
# 9130  California      Yes  Extended   College                  feb/2011
# 9131  California       No  Extended  Bachelor                  feb/2011
# 9132  California       No  Extended   College                  feb/2011
# 9133  California       No  Extended   College                  feb/2011
#
#      employmentstatus gender location_code marital_status        policy  \
# ...

# %%
# 10) Save the cleaned catagorical dataframe as categorical.csv
df_categ.to_csv(r"C:\Users\joaoa\Desktop\Ironhack\Labs\lab-cleaning-categorical-data\categorical.csv", index = False)
