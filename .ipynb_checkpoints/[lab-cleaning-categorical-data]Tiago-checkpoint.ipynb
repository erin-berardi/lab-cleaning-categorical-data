# %% [markdown]
# ### 1 Import the necessary libraries load the data and start a new notebook. Using the same data as the previous lab: we_fn_use_c_marketing_customer_value_analysis.csv

# %%
# !pip install jupyter_datatables
# Out:
# Collecting jupyter_datatables
#   Downloading jupyter_datatables-0.3.9-py2.py3-none-any.whl (21 kB)
# Collecting jupyter-require>=0.3.0
#   Downloading jupyter_require-0.6.1-py2.py3-none-any.whl (42 kB)
#      ---------------------------------------- 42.3/42.3 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.23.0 in c:\users\quaresma\anaconda3\lib\site-packages (from jupyter_datatables) (1.5.3)
# Requirement already satisfied: scipy in c:\users\quaresma\anaconda3\lib\site-packages (from jupyter_datatables) (1.10.0)
# Requirement already satisfied: ipykernel in c:\users\quaresma\anaconda3\lib\site-packages (from jupyter_datatables) (6.19.2)
# Requirement already satisfied: ipython in c:\users\quaresma\anaconda3\lib\site-packages (from jupyter_datatables) (8.10.0)
# Collecting jupyter-contrib-nbextensions
#   Downloading jupyter_contrib_nbextensions-0.7.0.tar.gz (23.5 MB)
#      ---------------------------------------- 23.5/23.5 MB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting jupyter-nbutils
#   Downloading jupyter_nbutils-0.1.3-py3-none-any.whl (7.7 kB)
# Collecting daiquiri
#   Downloading daiquiri-3.2.3-py3-none-any.whl (19 kB)
# Collecting csscompressor
#   Downloading csscompressor-0.9.5.tar.gz (237 kB)
#      -------------------------------------- 237.8/237.8 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\quaresma\anaconda3\lib\site-packages (from pandas>=0.23.0->jupyter_datatables) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\quaresma\anaconda3\lib\site-packages (from pandas>=0.23.0->jupyter_datatables) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\quaresma\anaconda3\lib\site-packages (from pandas>=0.23.0->jupyter_datatables) (1.23.5)
# Requirement already satisfied: debugpy>=1.0 in c:\users\quaresma\anaconda3\lib\site-packages (from ipykernel->jupyter_datatables) (1.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\quaresma\anaconda3\lib\site-packages (from ipykernel->jupyter_datatables) (5.7.1)
# Requirement already satisfied: psutil in c:\users\quaresma\anaconda3\lib\site-packages (from ipykernel->jupyter_datatables) (5.9.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\quaresma\anaconda3\lib\site-packages (from ipykernel->jupyter_datatables) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\quaresma\anaconda3\lib\site-packages (from ipykernel->jupyter_datatables) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\quaresma\anaconda3\lib\site-packages (from ipykernel->jupyter_datatables) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\quaresma\anaconda3\lib\site-packages (from ipykernel->jupyter_datatables) (6.1)
# Requirement already satisfied: nest-asyncio in c:\users\quaresma\anaconda3\lib\site-packages (from ipykernel->jupyter_datatables) (1.5.6)
# Requirement already satisfied: packaging in c:\users\quaresma\anaconda3\lib\site-packages (from ipykernel->jupyter_datatables) (22.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\quaresma\anaconda3\lib\site-packages (from ipykernel->jupyter_datatables) (0.1.2)
# Requirement already satisfied: pickleshare in c:\users\quaresma\anaconda3\lib\site-packages (from ipython->jupyter_datatables) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\quaresma\anaconda3\lib\site-packages (from ipython->jupyter_datatables) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\quaresma\anaconda3\lib\site-packages (from ipython->jupyter_datatables) (0.18.1)
# Requirement already satisfied: colorama in c:\users\quaresma\anaconda3\lib\site-packages (from ipython->jupyter_datatables) (0.4.6)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\quaresma\anaconda3\lib\site-packages (from ipython->jupyter_datatables) (2.11.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\quaresma\anaconda3\lib\site-packages (from ipython->jupyter_datatables) (3.0.36)
# Requirement already satisfied: decorator in c:\users\quaresma\anaconda3\lib\site-packages (from ipython->jupyter_datatables) (5.1.1)
# Requirement already satisfied: backcall in c:\users\quaresma\anaconda3\lib\site-packages (from ipython->jupyter_datatables) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\quaresma\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_datatables) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\quaresma\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_datatables) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\quaresma\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_datatables) (5.2.0)
# Requirement already satisfied: wcwidth in c:\users\quaresma\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython->jupyter_datatables) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\quaresma\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.23.0->jupyter_datatables) (1.16.0)
# Collecting python-json-logger
#   Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: ipython_genutils in c:\users\quaresma\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (0.2.0)
# Collecting jupyter_contrib_core>=0.3.3
#   Downloading jupyter_contrib_core-0.4.2.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting jupyter_highlight_selected_word>=0.1.1
#   Downloading jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting jupyter_nbextensions_configurator>=0.4.0
#   Downloading jupyter_nbextensions_configurator-0.6.3-py2.py3-none-any.whl (466 kB)
#      -------------------------------------- 466.9/466.9 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: nbconvert>=6.0 in c:\users\quaresma\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (6.5.4)
# Requirement already satisfied: notebook>=6.0 in c:\users\quaresma\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (6.5.2)
# Requirement already satisfied: lxml in c:\users\quaresma\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (4.9.1)
# Requirement already satisfied: pure-eval in c:\users\quaresma\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_datatables) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\quaresma\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_datatables) (2.0.5)
# Requirement already satisfied: executing in c:\users\quaresma\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_datatables) (0.8.3)
# Requirement already satisfied: setuptools in c:\users\quaresma\anaconda3\lib\site-packages (from jupyter_contrib_core>=0.3.3->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (65.6.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\quaresma\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->jupyter_datatables) (2.5.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\quaresma\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->jupyter_datatables) (305.1)
# Requirement already satisfied: pyyaml in c:\users\quaresma\anaconda3\lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (6.0)
# Requirement already satisfied: jinja2>=3.0 in c:\users\quaresma\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (3.1.2)
# Requirement already satisfied: bleach in c:\users\quaresma\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\quaresma\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\quaresma\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\quaresma\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\quaresma\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (4.11.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\quaresma\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (0.5.13)
# Requirement already satisfied: tinycss2 in c:\users\quaresma\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (1.2.1)
# Requirement already satisfied: defusedxml in c:\users\quaresma\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\quaresma\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (0.1.2)
# Requirement already satisfied: nbformat>=5.1 in c:\users\quaresma\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (5.7.0)
# Requirement already satisfied: prometheus-client in c:\users\quaresma\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (0.14.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\quaresma\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\quaresma\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (0.17.1)
# Requirement already satisfied: argon2-cffi in c:\users\quaresma\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (21.3.0)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\quaresma\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (0.5.2)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\quaresma\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\quaresma\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (0.2.2)
# Requirement already satisfied: fastjsonschema in c:\users\quaresma\anaconda3\lib\site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\quaresma\anaconda3\lib\site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (4.17.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\quaresma\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\quaresma\anaconda3\lib\site-packages (from argon2-cffi->notebook>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\quaresma\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\quaresma\anaconda3\lib\site-packages (from bleach->nbconvert>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (0.5.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\quaresma\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\quaresma\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (22.1.0)
# Requirement already satisfied: websocket-client in c:\users\quaresma\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (0.58.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\quaresma\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (3.5.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\quaresma\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (1.15.1)
# Requirement already satisfied: idna>=2.8 in c:\users\quaresma\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\quaresma\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\quaresma\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter-contrib-nbextensions->jupyter-require>=0.3.0->jupyter_datatables) (2.21)
# Building wheels for collected packages: csscompressor, jupyter-contrib-nbextensions, jupyter_contrib_core
#   Building wheel for csscompressor (setup.py): started
#   Building wheel for csscompressor (setup.py): finished with status 'done'
#   Created wheel for csscompressor: filename=csscompressor-0.9.5-py3-none-any.whl size=240353 sha256=d67776b177b522978588b5a3e57df8cf372bed0fd6e8d97ca3c7aeb17da10cfe
#   Stored in directory: c:\users\quaresma\appdata\local\pip\cache\wheels\74\75\00\e4b2f02c36016a6df23980e58d041705aa9bea376b1600d42f
#   Building wheel for jupyter-contrib-nbextensions (setup.py): started
#   Building wheel for jupyter-contrib-nbextensions (setup.py): finished with status 'done'
#   Created wheel for jupyter-contrib-nbextensions: filename=jupyter_contrib_nbextensions-0.7.0-py2.py3-none-any.whl size=23428802 sha256=d51982e49e24d62229b34a9e16a2baf5cbbcac4d5193467c3f90eff53484e173
#   Stored in directory: c:\users\quaresma\appdata\local\pip\cache\wheels\44\a7\44\406684ced6e1131cbfce3391ab8508a39857e215c5498c4e6b
#   Building wheel for jupyter_contrib_core (setup.py): started
#   Building wheel for jupyter_contrib_core (setup.py): finished with status 'done'
#   Created wheel for jupyter_contrib_core: filename=jupyter_contrib_core-0.4.2-py2.py3-none-any.whl size=17498 sha256=b51ddd90fe7055fc250d273fcc7129af549506928c30e5b246e00fca08ab5f03
#   Stored in directory: c:\users\quaresma\appdata\local\pip\cache\wheels\22\48\07\905faed53d1593772d705f08a979f218f8a6caa91f186895e4
# Successfully built csscompressor jupyter-contrib-nbextensions jupyter_contrib_core
# Installing collected packages: jupyter_highlight_selected_word, csscompressor, python-json-logger, daiquiri, jupyter_contrib_core, jupyter_nbextensions_configurator, jupyter-contrib-nbextensions, jupyter-nbutils, jupyter-require, jupyter_datatables
# Successfully installed csscompressor-0.9.5 daiquiri-3.2.3 jupyter-contrib-nbextensions-0.7.0 jupyter-nbutils-0.1.3 jupyter-require-0.6.1 jupyter_contrib_core-0.4.2 jupyter_datatables-0.3.9 jupyter_highlight_selected_word-0.2.0 jupyter_nbextensions_configurator-0.6.3 python-json-logger-2.0.7

# %%
import imblearn
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report,accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.utils import resample
from imblearn.over_sampling import SMOTE

from jupyter_datatables import init_datatables_mode

# %%
init_datatables_mode()
# Out:
# ---------------------------------------------------------------------------
# CommError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 init_datatables_mode()
#
# File ~\anaconda3\lib\site-packages\jupyter_datatables\__init__.py:96, in init_datatables_mode(options, classes)
#      93 # extensions to be loaded
#      94 extensions = config.defaults.extensions
# ---> 96 require("d3", "https://d3js.org/d3.v5.min")
#      97 require("d3-array", "https://d3js.org/d3-array.v2.min")
#      99 require.config(**{
#     100     "paths": {
#     101         "moment": "https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.8.0/moment",
#    (...)
#     109     },
#     110 })
#
# File ~\anaconda3\lib\site-packages\jupyter_require\core.py:112, in RequireJS.__call__(self, library, path, *args, **kwargs)
#      98 def __call__(self, library: str, path: str, *args, **kwargs):
#      99     """Links JavaScript library to Jupyter Notebook.
#     100
#     101     The library is linked using requireJS such as:
#    (...)
#     110     :param path: str, path (url) to the library without .js suffix
#     111     """
# --> 112     self.config({library: path}, shim=kwargs.pop('shim', {}))
#
# File ~\anaconda3\lib\site-packages\jupyter_require\core.py:201, in RequireJS.config(self, paths, shim)
#     195 logger.debug("Configuration requested: %s", {
#     196     "paths": paths,
#     197     "shim": shim
#     198 })
#     200 if not self.is_initialized:
# --> 201     raise CommError("Comms haven't been initialized properly.")
#     203 RequireJS.__LIBS.update(paths)
#     204 RequireJS.__SHIM.update(shim or {})
#
# CommError: Comms haven't been initialized properly.. HINT: Try reloading <F5> the window.

# %%
data=pd.read_csv(r"C:\Users\Quaresma\Documents\IRONHACK\Labs\11 lab-cleaning-categorical-data\files_for_lab\we_fn_use_c_marketing_customer_value_analysis.csv")

# %%
data
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# 0     Bachelor           2/24/11         Employed      F   56274  ...
# 1     Bachelor           1/31/11       Unemployed      F       0  ...
# 2     Bachelor           2/19/11         Employed      F   48767  ...
# 3     Bachelor           1/20/11       Unemployed      M       0  ...
# 4     Bachelor            2/3/11         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9129  Bachelor           2/10/11         Employed      M   71941  ...
# 9130   College           2/12/11         Employed      F   21604  ...
# 9131  Bachelor            2/6/11       Unemployed      M       0  ...
# 9132   College            2/3/11         Employed      M   21941  ...
# 9133   College           2/14/11       Unemployed      M       0  ...
#
#      Months Since Policy Inception Number of Open Complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#       Sales Channel Total Claim Amount  Vehicle Class Vehicle Size
# 0             Agent         384.811147   Two-Door Car      Medsize
# 1             Agent        1131.464935  Four-Door Car      Medsize
# 2             Agent         566.472247   Two-Door Car      Medsize
# 3       Call Center         529.881344            SUV      Medsize
# 4             Agent         138.130879  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9129            Web         198.234764  Four-Door Car      Medsize
# 9130         Branch         379.200000  Four-Door Car      Medsize
# 9131         Branch         790.784983  Four-Door Car      Medsize
# 9132         Branch         691.200000  Four-Door Car        Large
# 9133    Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]

# %%
col=[data.columns[i].lower().replace(" ","_") for i in range(len(data.columns))]
data.columns=col

# %% [markdown]
# ### 2 Find all of the categorical data. Save it in a categorical_df variable.

# %%
categorical_df= data.select_dtypes(include=np.object)
categorical_df
# Out:
#      customer       state response  coverage education effective_to_date  \
# 0     BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1     QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2     AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3     WW63253  California       No     Basic  Bachelor           1/20/11
# 4     HB64268  Washington       No     Basic  Bachelor            2/3/11
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor           2/10/11
# 9130  PK87824  California      Yes  Extended   College           2/12/11
# 9131  TD14365  California       No  Extended  Bachelor            2/6/11
# 9132  UP19263  California       No  Extended   College            2/3/11
# 9133  Y167826  California       No  Extended   College           2/14/11
#
#      employmentstatus gender location_code marital_status     policy_type  \
# 0            Employed      F      Suburban        Married  Corporate Auto
# 1          Unemployed      F      Suburban         Single   Personal Auto
# 2            Employed      F      Suburban        Married   Personal Auto
# 3          Unemployed      M      Suburban        Married  Corporate Auto
# 4            Employed      M         Rural         Single   Personal Auto
# ...               ...    ...           ...            ...             ...
# 9129         Employed      M         Urban        Married   Personal Auto
# 9130         Employed      F      Suburban       Divorced  Corporate Auto
# 9131       Unemployed      M      Suburban         Single  Corporate Auto
# 9132         Employed      M      Suburban        Married   Personal Auto
# 9133       Unemployed      M      Suburban         Single  Corporate Auto
#
#             policy renew_offer_type sales_channel  vehicle_class vehicle_size
# 0     Corporate L3           Offer1         Agent   Two-Door Car      Medsize
# 1      Personal L3           Offer3         Agent  Four-Door Car      Medsize
# 2      Personal L3           Offer1         Agent   Two-Door Car      Medsize
# 3     Corporate L2           Offer1   Call Center            SUV      Medsize
# 4      Personal L1           Offer1         Agent  Four-Door Car      Medsize
# ...            ...              ...           ...            ...          ...
# 9129   Personal L1           Offer2           Web  Four-Door Car      Medsize
# 9130  Corporate L3           Offer1        Branch  Four-Door Car      Medsize
# 9131  Corporate L2           Offer1        Branch  Four-Door Car      Medsize
# 9132   Personal L2           Offer3        Branch  Four-Door Car        Large
# 9133  Corporate L3           Offer4   Call Center   Two-Door Car      Medsize
#
# [9134 rows x 16 columns]

# %% [markdown]
# ### 3 Check for NaN values and decide what to do with them, do it now.

# %%
categorical_df.isna().sum()  # Since we dont have, lets proceed
# Out:
# customer             0
# state                0
# response             0
# coverage             0
# education            0
# effective_to_date    0
# employmentstatus     0
# gender               0
# location_code        0
# marital_status       0
# policy_type          0
# policy               0
# renew_offer_type     0
# sales_channel        0
# vehicle_class        0
# vehicle_size         0
# dtype: int64

# %% [markdown]
# ### 4 Check all unique values of columns

# %%
categorical_df.nunique()
# Out:
# customer             9134
# state                   5
# response                2
# coverage                3
# education               5
# effective_to_date      59
# employmentstatus        5
# gender                  2
# location_code           3
# marital_status          3
# policy_type             3
# policy                  9
# renew_offer_type        4
# sales_channel           4
# vehicle_class           6
# vehicle_size            3
# dtype: int64

# %% [markdown]
# ### 5 Check dtypes. Do they all make sense as categorical data?

# %%
categorical_df.dtypes # makes sense, the only ones I think dont make sense are the customer since is de ID and effective_to_date
# Out:
# customer             object
# state                object
# response             object
# coverage             object
# education            object
# effective_to_date    object
# employmentstatus     object
# gender               object
# location_code        object
# marital_status       object
# policy_type          object
# policy               object
# renew_offer_type     object
# sales_channel        object
# vehicle_class        object
# vehicle_size         object
# dtype: object

# %% [markdown]
# ### 6 Would you choose to do anything else to clean or wrangle the categorical data? Comment your decisions and do it now.
