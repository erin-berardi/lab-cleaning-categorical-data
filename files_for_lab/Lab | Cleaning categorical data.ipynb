# %% [markdown]
# # Data Analysis Process

# %% [markdown]
# # Remember the process:
#
# Case Study
#
# Get data
#
# Cleaning/Wrangling/EDA
#
# Processing Data
#
# Modeling -Validation
#
# Reporting

# %% [raw]
# # Instructions
# 1.Import the necessary libraries load the data and start a new notebook. Using the same data as the previous lab: we_fn_use_c_marketing_customer_value_analysis.csv
#
# 2.Find all of the categorical data. Save it in a categorical_df variable.
#
# 3.Check for NaN values and decide what to do with them, do it now.
#
# 4.Check all unique values of columns.
#
# 5.Check dtypes. Do they all make sense as categorical data?
#
# 6.Does any column contain alpha and numeric data? Decide how to clean it and do it now.
#
# 7.Would you choose to do anything else to clean or wrangle the categorical data? Comment your decisions and do it now.
#
# 8.Compare policy_type and policy. What information is contained in these columns. Can you identify what is important?
#
# 9.Check number of unique values in each column, can they be combined in any way to ease encoding? Comment your thoughts and make those changes.
#
# 10.Save the cleaned catagorical dataframe as categorical.csv You will use this file again this week.

# %% [raw]
# 1.Import the necessary libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %% [raw]
# 2.Find all of the categorical data. Save it in a categorical_df variable.

# %%
categorical_df = data.select_dtypes(object)

# %%
categorical_df
# Out:
#      Customer       State Response  Coverage Education Effective To Date  \
# 0     BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1     QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2     AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3     WW63253  California       No     Basic  Bachelor           1/20/11
# 4     HB64268  Washington       No     Basic  Bachelor            2/3/11
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor           2/10/11
# 9130  PK87824  California      Yes  Extended   College           2/12/11
# 9131  TD14365  California       No  Extended  Bachelor            2/6/11
# 9132  UP19263  California       No  Extended   College            2/3/11
# 9133  Y167826  California       No  Extended   College           2/14/11
#
#      EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %% [raw]
# 3.Check for NaN values and decide what to do with them, do it now.

# %%
(categorical_df.isna().sum()/len(categorical_df)).sort_values(ascending=False)
# Out:
# Customer             0.0
# State                0.0
# Response             0.0
# Coverage             0.0
# Education            0.0
# Effective To Date    0.0
# EmploymentStatus     0.0
# Gender               0.0
# Location Code        0.0
# Marital Status       0.0
# Policy Type          0.0
# Policy               0.0
# Renew Offer Type     0.0
# Sales Channel        0.0
# Vehicle Class        0.0
# Vehicle Size         0.0
# dtype: float64

# %% [raw]
# There are no null values

# %% [raw]
# 4.Check all unique values of columns.

# %%
categorical_df.nunique()
# Out:
# Customer             9134
# State                   5
# Response                2
# Coverage                3
# Education               5
# Effective To Date      59
# EmploymentStatus        5
# Gender                  2
# Location Code           3
# Marital Status          3
# Policy Type             3
# Policy                  9
# Renew Offer Type        4
# Sales Channel           4
# Vehicle Class           6
# Vehicle Size            3
# dtype: int64

# %% [raw]
# 5.Check dtypes. Do they all make sense as categorical data?

# %%
categorical_df.dtypes
# Out:
# Customer             object
# State                object
# Response             object
# Coverage             object
# Education            object
# Effective To Date    object
# EmploymentStatus     object
# Gender               object
# Location Code        object
# Marital Status       object
# Policy Type          object
# Policy               object
# Renew Offer Type     object
# Sales Channel        object
# Vehicle Class        object
# Vehicle Size         object
# dtype: object

# %%
categorical_df['Effective To Date']= pd.to_datetime(categorical_df['Effective To Date'])

# %%
categorical_df.dtypes
# Out:
# Customer                     object
# State                        object
# Response                     object
# Coverage                     object
# Education                    object
# Effective To Date    datetime64[ns]
# EmploymentStatus             object
# Gender                       object
# Location Code                object
# Marital Status               object
# Policy Type                  object
# Policy                       object
# Renew Offer Type             object
# Sales Channel                object
# Vehicle Class                object
# Vehicle Size                 object
# dtype: object

# %% [raw]
# 6.Does any column contain alpha and numeric data? Decide how to clean it and do it now.

# %%
categorical_df
# Out:
#      Customer       State Response  Coverage Education Effective To Date  \
# 0     BU79786  Washington       No     Basic  Bachelor        2011-02-24
# 1     QZ44356     Arizona       No  Extended  Bachelor        2011-01-31
# 2     AI49188      Nevada       No   Premium  Bachelor        2011-02-19
# 3     WW63253  California       No     Basic  Bachelor        2011-01-20
# 4     HB64268  Washington       No     Basic  Bachelor        2011-02-03
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor        2011-02-10
# 9130  PK87824  California      Yes  Extended   College        2011-02-12
# 9131  TD14365  California       No  Extended  Bachelor        2011-02-06
# 9132  UP19263  California       No  Extended   College        2011-02-03
# 9133  Y167826  California       No  Extended   College        2011-02-14
#
#      EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %%
categorical_df.columns
# Out:
# Index(['Customer', 'State', 'Response', 'Coverage', 'Education',
#        'Effective To Date', 'EmploymentStatus', 'Gender', 'Location Code',
#        'Marital Status', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
categorical_df['customer_id'] = categorical_df['Customer'].str.extract('(\d+)')
categorical_df['Customer'] = categorical_df['Customer'].str.replace('\d+', '')
# Out:
# /var/folders/13/xty849950wj5f71_v7v6vysc0000gn/T/ipykernel_53499/1352036501.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   categorical_df['Customer'] = categorical_df['Customer'].str.replace('\d+', '')

# %%
categorical_df
# Out:
#      Customer       State Response  Coverage Education Effective To Date  \
# 0          BU  Washington       No     Basic  Bachelor        2011-02-24
# 1          QZ     Arizona       No  Extended  Bachelor        2011-01-31
# 2          AI      Nevada       No   Premium  Bachelor        2011-02-19
# 3          WW  California       No     Basic  Bachelor        2011-01-20
# 4          HB  Washington       No     Basic  Bachelor        2011-02-03
# ...       ...         ...      ...       ...       ...               ...
# 9129       LA  California       No     Basic  Bachelor        2011-02-10
# 9130       PK  California      Yes  Extended   College        2011-02-12
# 9131       TD  California       No  Extended  Bachelor        2011-02-06
# 9132       UP  California       No  Extended   College        2011-02-03
# 9133        Y  California       No  Extended   College        2011-02-14
#
#      EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %%
categorical_df[['policy', 'policy Alpha']] = categorical_df['Policy'].str.split(expand=True)
categorical_df['Policy'] = categorical_df['policy']
categorical_df.drop(['policy'],axis=1,inplace=True)

# %%
categorical_df
# Out:
#      Customer       State Response  Coverage Education Effective To Date  \
# 0          BU  Washington       No     Basic  Bachelor        2011-02-24
# 1          QZ     Arizona       No  Extended  Bachelor        2011-01-31
# 2          AI      Nevada       No   Premium  Bachelor        2011-02-19
# 3          WW  California       No     Basic  Bachelor        2011-01-20
# 4          HB  Washington       No     Basic  Bachelor        2011-02-03
# ...       ...         ...      ...       ...       ...               ...
# 9129       LA  California       No     Basic  Bachelor        2011-02-10
# 9130       PK  California      Yes  Extended   College        2011-02-12
# 9131       TD  California       No  Extended  Bachelor        2011-02-06
# 9132       UP  California       No  Extended   College        2011-02-03
# 9133        Y  California       No  Extended   College        2011-02-14
#
#      EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %%
categorical_df['Renew Offer Type_num'] = categorical_df['Renew Offer Type'].str.extract('(\d+)')
categorical_df['Renew Offer Type'] = categorical_df['Renew Offer Type'].str.replace('\d+', '')
# Out:
# /var/folders/13/xty849950wj5f71_v7v6vysc0000gn/T/ipykernel_53499/2698511212.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   categorical_df['Renew Offer Type'] = categorical_df['Renew Offer Type'].str.replace('\d+', '')

# %%
categorical_df
# Out:
#      Customer       State Response  Coverage Education Effective To Date  \
# 0          BU  Washington       No     Basic  Bachelor        2011-02-24
# 1          QZ     Arizona       No  Extended  Bachelor        2011-01-31
# 2          AI      Nevada       No   Premium  Bachelor        2011-02-19
# 3          WW  California       No     Basic  Bachelor        2011-01-20
# 4          HB  Washington       No     Basic  Bachelor        2011-02-03
# ...       ...         ...      ...       ...       ...               ...
# 9129       LA  California       No     Basic  Bachelor        2011-02-10
# 9130       PK  California      Yes  Extended   College        2011-02-12
# 9131       TD  California       No  Extended  Bachelor        2011-02-06
# 9132       UP  California       No  Extended   College        2011-02-03
# 9133        Y  California       No  Extended   College        2011-02-14
#
#      EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %% [raw]
# 7.Would you choose to do anything else to clean or wrangle the categorical data? Comment your decisions and do it now.

# %%
categorical_df.nunique()
# Out:
# Customer                 677
# State                      5
# Response                   2
# Coverage                   3
# Education                  5
# Effective To Date         59
# EmploymentStatus           5
# Gender                     2
# Location Code              3
# Marital Status             3
# Policy Type                3
# Policy                     3
# Renew Offer Type           1
# Sales Channel              4
# Vehicle Class              6
# Vehicle Size               3
# customer_id             8688
# policy Alpha               3
# Renew Offer Type_num       4
# dtype: int64

# %%
categorical_df.drop(['customer_id'],axis=1,inplace=True) # Have a lot of unique values

# %%
categorical_df.drop(['policy Alpha'],axis=1,inplace=True) # The column is not significante to the model

# %%
categorical_df.drop(['Renew Offer Type'],axis=1,inplace=True)  # The column is not significante to the model

# %%
categorical_df
# Out:
#      Customer       State Response  Coverage Education Effective To Date  \
# 0          BU  Washington       No     Basic  Bachelor        2011-02-24
# 1          QZ     Arizona       No  Extended  Bachelor        2011-01-31
# 2          AI      Nevada       No   Premium  Bachelor        2011-02-19
# 3          WW  California       No     Basic  Bachelor        2011-01-20
# 4          HB  Washington       No     Basic  Bachelor        2011-02-03
# ...       ...         ...      ...       ...       ...               ...
# 9129       LA  California       No     Basic  Bachelor        2011-02-10
# 9130       PK  California      Yes  Extended   College        2011-02-12
# 9131       TD  California       No  Extended  Bachelor        2011-02-06
# 9132       UP  California       No  Extended   College        2011-02-03
# 9133        Y  California       No  Extended   College        2011-02-14
#
#      EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %% [raw]
# 8.Compare policy_type and policy. What information is contained in these columns. Can you identify what is important?

# %%
categorical_df['Policy Type'].value_counts()
# Out:
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: Policy Type, dtype: int64

# %%
categorical_df['Policy'].value_counts()
# Out:
# Personal     6788
# Corporate    1968
# Special       378
# Name: Policy, dtype: int64

# %% [raw]
# In this two columns the most importante is if the policy is Personal, Corporate or Special. So i can drop the "Policy Type" column because ia take the same information from on "Policy" column.

# %% [raw]
# 9.Check number of unique values in each column, can they be combined in any way to ease encoding? Comment your thoughts and make those changes.

# %% [raw]
# The Customer column has 677 and Effective To Date has 59 unique values, which makes it hard to encode it without adding too many features.
# So  in the case of Customer column is better to drop and extract the Year form the Effective to Date and create a new column. After this, all columns stay with lower unique values and it makes more easier to encode.

# %%
categorical_df.nunique()
# Out:
# Customer                677
# State                     5
# Response                  2
# Coverage                  3
# Education                 5
# Effective To Date        59
# EmploymentStatus          5
# Gender                    2
# Location Code             3
# Marital Status            3
# Policy Type               3
# Policy                    3
# Sales Channel             4
# Vehicle Class             6
# Vehicle Size              3
# Renew Offer Type_num      4
# dtype: int64

# %%
categorical_df.drop(['Customer'],axis=1,inplace=True)

# %%
categorical_df['Year'] = categorical_df['Effective To Date'].dt.year

# %%
categorical_df.drop(['Effective To Date'],axis=1,inplace=True)

# %%
categorical_df.nunique()
# Out:
# State                   5
# Response                2
# Coverage                3
# Education               5
# EmploymentStatus        5
# Gender                  2
# Location Code           3
# Marital Status          3
# Policy Type             3
# Policy                  3
# Sales Channel           4
# Vehicle Class           6
# Vehicle Size            3
# Renew Offer Type_num    4
# Year                    1
# dtype: int64

# %% [raw]
# 10.Save the cleaned catagorical dataframe as categorical.csv You will use this file again this week.

# %%
categorical_df.to_csv("categorical.csv")
